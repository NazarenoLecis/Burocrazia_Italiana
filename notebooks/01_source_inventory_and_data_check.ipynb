# %% [markdown]
# # 01. Inventario delle fonti e controllo dei dati
#
# Verifica fonti censite, stato dei connettori, file disponibili e principali controlli di qualità.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from IPython.display import display

from scripts.config import QUALITY_DATA_DIR, SOURCE_FILE_NAMES
from scripts.src.build_source_inventory import build_source_inventory
from scripts.utils import read_dataframe

# %%
source_inventory = build_source_inventory()
display(source_inventory)

# %%
source_summary = (
    source_inventory
    .groupby(["source_category", "status"], dropna=False)
    .size()
    .rename("source_count")
    .reset_index()
)
display(source_summary)

# %%
quality_path = QUALITY_DATA_DIR / SOURCE_FILE_NAMES["data_quality_report"]
if quality_path.exists():
    quality_report = read_dataframe(quality_path)
    display(quality_report)
else:
    print("Il report di qualità sarà disponibile dopo l'esecuzione della pipeline.")
