# %% [markdown]
# # 05. Output finali
#
# Aggiorna indicatori, controlli di qualità e grafici. Presenta una sintesi descrittiva con fonti e limitazioni.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from IPython.display import display

from scripts.src.build_bureaucracy_indicators import build_bureaucracy_indicators
from scripts.src.build_source_inventory import build_source_inventory
from scripts.src.build_territorial_comparisons import build_territorial_comparisons
from scripts.src.check_data_quality import check_data_quality
from scripts.src.make_bureaucracy_charts import make_bureaucracy_charts

# %%
source_inventory = build_source_inventory()
indicators = build_bureaucracy_indicators()
comparisons = build_territorial_comparisons()
quality_report = check_data_quality()
chart_paths = make_bureaucracy_charts()

# %%
display(indicators.head(20))
display(quality_report.loc[quality_report["check_status"] != "pass"])
print("Grafici prodotti:")
for path in chart_paths:
    print(f"- {path}")

# %% [markdown]
# ## Guida all'interpretazione
#
# Gli indicatori IPA descrivono la completezza e la distribuzione dell'anagrafica. Gli indicatori Eurostat descrivono l'uso dei servizi pubblici online. Nessuno dei due gruppi misura direttamente costi, documenti o tempi dei procedimenti. I confronti devono essere letti insieme a copertura, numerosità e fonte.
