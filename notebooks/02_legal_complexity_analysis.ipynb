# %% [markdown]
# # 02. Analisi della complessità normativa
#
# Prepara atti e disposizioni, controlla la copertura e analizza i flag candidati senza interpretarli come misura automatica dell'onere.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from IPython.display import display

from scripts.config import CLEAN_DATA_DIR, SOURCE_FILE_NAMES
from scripts.src.clean_legal_data import clean_legal_data
from scripts.utils import read_dataframe

# %%
legal_acts, legal_provisions = clean_legal_data()
print(f"Atti disponibili: {len(legal_acts):,}")
print(f"Disposizioni disponibili: {len(legal_provisions):,}")

# %%
if legal_provisions.empty:
    print("Il connettore Normattiva non è ancora implementato. Non sono stati creati record simulati.")
else:
    candidate_columns = [column for column in legal_provisions if column.startswith("candidate_")]
    display(legal_provisions[candidate_columns].sum().sort_values(ascending=False))

# %%
acts_path = CLEAN_DATA_DIR / SOURCE_FILE_NAMES["legal_acts_clean"]
provisions_path = CLEAN_DATA_DIR / SOURCE_FILE_NAMES["legal_provisions_clean"]
print(acts_path)
print(provisions_path)
